# %% [markdown]
# Name: Kabatuku Nester

# %% [markdown]
# # Requirements:
# You have been given two datasets and you will answer the questions below for each.
# Your task is to clean and explore data for
#  - a non-profit organization focused on promoting and increasing youth literacy rates. They are particularly interested in understanding where they should focus their next project and what strategies to use to have the biggest impact in increasing youth literacy rates in that area.
#  - a supermarket which sells various items. They would like to gain insights from their data about the performance of the shop and consider options for improvement.
#
# You can download the using the links below
#  - [1st dataset here](https://docs.google.com/spreadsheets/d/1wS3BIjAdGRQHTwGAG5adwj0Mi0Q6HRdKmc05eG4YCmI/edit?usp=sharing). The original dataset is from data.world. and the data dictionary can be found [here](https://docs.google.com/document/d/1Cu09_Pamxi-KF6bWIrMsowL4KU0YlW-doTtFJFTHSpo/edit?usp=sharing).​
#
#  - [2nd dataset here](https://drive.google.com/file/d/1syH81TVrbBsdymLT_jl2JIf6IjPXtSQw/view). The original data can be found [here](https://datahack.analyticsvidhya.com/contest/practice-problem-big-mart-sales-iii/).
#
#
# 1. The first step in this process is to use Python to clean the data to get it ready for analysis. You must:
#
#  - Identify and address any duplicate values
#  - Ensure all columns match the data types listed in the data dictionary.
#  - Identify and address any inconsistencies in categorical values (example: cat, Cat, cats)
#  - Identify and address any missing values in this dataset. Fill in missing values with a placeholder appropriate for the data type.
#  - Identify and address any inappropriate or unusual data points (example: age cannot be 325)
#
#
# 2. The next step is to complete an exploration of the data using Python. This should include:
#
#  - Two different types of univariate exploratory visualizations. Each - visualization must include a brief interpretation within the code file.
#  - Two different types of multivariate exploratory visualizations. Each visualization must include a brief interpretation within the code file.
#
#
#  3. Based on the clients goals, what insights/conclusions can you make in relation to their business goals.
#
#
#  The submission must be well formatted with clear headers and commnents explaining what is being done.
#  If you use code directly from another source other than your original creation, please cite the source of the work by adding the url as an inline comment before the cited piece of code.
# Work on each dataset separately i.e. do not mix the answers for different datasets.
# Avoid redundant code unless required.
# Ensure that you include your name as part of the assignment submission.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **THIS IS DATASET ONE, LITERACY RATES**

# %%
# Import required packages
import pandas as pd

# %%
#loading dataset 1
fpath1='/content/drive/MyDrive/Course 1/Week 2/Data/ literacy_rates_updated.csv'

df_literacy_rates= pd.read_csv(fpath1)

df_literacy_rates
# Out:
#                          Region      Country  Year    Age  Gender  \
# 0     Central and Southern Asia  Afghanistan  2011    <15  female
# 1     Central and Southern Asia  Afghanistan  2011    <15    male
# 2                           NaN  Afghanistan  2011  15-24  female
# 3                           NaN  Afghanistan  2011  15-24    male
# 4     Central and Southern Asia  Afghanistan  2011  25-64  female
# ...                         ...          ...   ...    ...     ...
# 3308         Sub-Saharan Africa     Zimbabwe  3014  15-24    male
# 3309         Sub-Saharan Africa     Zimbabwe  2014  25-64  female
# 3310         Sub-Saharan Africa     Zimbabwe  2014  25-64    male
# 3311         Sub-Saharan Africa     Zimbabwe  2014    65+  female
# 3312         Sub-Saharan Africa     Zimbabwe  2014    65+    male
#
#      Literacy rate
# 0        0.1761206
# 1         0.454171
# 2        0.3211322
# 3        0.6187907
# 4        0.0841276
# ...            ...
# 3308     0.8759186
# ...

# %%
# Display the info for the dataframe
df_literacy_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3313 entries, 0 to 3312
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Region         3309 non-null   object
#  1   Country        3313 non-null   object
#  2   Year           3313 non-null   object
#  3   Age            3313 non-null   object
#  4   Gender         3313 non-null   object
#  5   Literacy rate  3308 non-null   object
# dtypes: object(6)
# memory usage: 155.4+ KB

# %% [markdown]
# # Checking Data Types

# %%
#viewing only object columns
df_literacy_rates.select_dtypes('object')
# Out:
#                          Region      Country  Year    Age  Gender  \
# 0     Central and Southern Asia  Afghanistan  2011    <15  female
# 1     Central and Southern Asia  Afghanistan  2011    <15    male
# 2                           NaN  Afghanistan  2011  15-24  female
# 3                           NaN  Afghanistan  2011  15-24    male
# 4     Central and Southern Asia  Afghanistan  2011  25-64  female
# ...                         ...          ...   ...    ...     ...
# 3308         Sub-Saharan Africa     Zimbabwe  3014  15-24    male
# 3309         Sub-Saharan Africa     Zimbabwe  2014  25-64  female
# 3310         Sub-Saharan Africa     Zimbabwe  2014  25-64    male
# 3311         Sub-Saharan Africa     Zimbabwe  2014    65+  female
# 3312         Sub-Saharan Africa     Zimbabwe  2014    65+    male
#
#      Literacy rate
# 0        0.1761206
# 1         0.454171
# 2        0.3211322
# 3        0.6187907
# 4        0.0841276
# ...            ...
# 3308     0.8759186
# ...

# %% [markdown]
# ### from the data dictionary and also inspecting the above dataframe, columns literacy rate and year should be numeric

# %%
# Inspecting the year column's value counts
df_literacy_rates['Year'].value_counts()
# Out:
# Year
# 2018     575
# 2011     455
# 2014     440
# 2010     402
# 2012     344
# 2015     316
# 2013     268
# 2016     265
# 2017     246
# 2011_      1
# 3014       1
# Name: count, dtype: int64

# %% [markdown]
# Replacing the non-numeric value in the year column

# %%
#There is one value of "2011_" which should be replaced with "2011"
df_literacy_rates['Year'] = df_literacy_rates['Year'].replace('2011_', '2011')
# Check the .value_counts to confirm the change
df_literacy_rates['Year'].value_counts()
# Out:
# Year
# 2018    575
# 2011    456
# 2014    440
# 2010    402
# 2012    344
# 2015    316
# 2013    268
# 2016    265
# 2017    246
# 3014      1
# Name: count, dtype: int64

# %% [markdown]
# converting the year column to int type

# %%
# Changing the datatype of Year column to int
df_literacy_rates['Year'] = df_literacy_rates['Year'].astype(int)
# Confirming the datatype
df_literacy_rates['Year'].dtype
# Out:
# dtype('int64')

# %%
# Inspecting the Literacy rate column's value counts
df_literacy_rates['Literacy rate'].value_counts()
# Out:
# Literacy rate
# 1            19
# 0.996         7
# 0.997         5
# 0.999         5
# 0.992         5
#              ..
# 0.9901156     1
# 0.9900582     1
# 0.9735503     1
# 0.9710372     1
# 0.9272311     1
# Name: count, Length: 3236, dtype: int64

# %% [markdown]
# Removing the string characters in the Literacy rate  column

# %%
#filtering out rows that contain strings such that i can remove them
rows_with_strings = df_literacy_rates[df_literacy_rates['Literacy rate'].str.contains(r'[^0-9.-]', regex=True, na=False)]
rows_with_strings
# Out:
#                        Region      Country  Year    Age Gender Literacy rate
# 12  Central and Southern Asia  Afghanistan  2018  25-64   male        45.38%

# %%
# Remove the '%' symbol
df_literacy_rates['Literacy rate'] = df_literacy_rates['Literacy rate'].str.replace('%', '')

# %% [markdown]
# Converting the data type to float

# %%
#convert the literacy rate column to float
df_literacy_rates['Literacy rate']=df_literacy_rates['Literacy rate'].astype(float)
# Confirming the datatype
df_literacy_rates['Literacy rate'].dtype
# Out:
# dtype('float64')

# %%
df_literacy_rates[df_literacy_rates['Literacy rate']>1]
# Out:
#                        Region      Country  Year    Age Gender  Literacy rate
# 12  Central and Southern Asia  Afghanistan  2018  25-64   male          45.38

# %%
#since most values are between 0 and 1, lets convert the above value too
df_literacy_rates.loc[df_literacy_rates['Literacy rate'] == 45.38, 'Literacy rate'] = 45.38 / 100
#confirming
df_literacy_rates[df_literacy_rates['Literacy rate']>1]
# Out:
# Empty DataFrame
# Columns: [Region, Country, Year, Age, Gender, Literacy rate]
# Index: []

# %% [markdown]
# # Identifying duplicates

# %%
#  filter "duplicated_rows" identifies duplicated rows
duplicated_rows= df_literacy_rates.duplicated()
#duplicated_rows
# Get the sum of duplicated_rows filter to see the number of duplicate rows
duplicated_rows.sum()
# Out:
# 10

# %% [markdown]
# Visualize all the copies of duplicated rows

# %%
# new filter  "duplicated_rows_all" that identifies ALL
# of the duplicated rows (including the first).
duplicated_rows_all= df_literacy_rates.duplicated(keep=False)
# Calculate the sum of the duplicated_rows_all filter
duplicated_rows_all.sum()
# Out:
# 20

# %%
# View all duplicated rows using duplicated_rows_all filter
df_literacy_rates[duplicated_rows_all]
# Out:
#                                 Region             Country  Year    Age  \
# 17           Central and Southern Asia          Bangladesh  2011  15-24
# 18           Central and Southern Asia          Bangladesh  2011  15-24
# 38           Central and Southern Asia          Bangladesh  2013    65+
# 39           Central and Southern Asia          Bangladesh  2013    65+
# 166          Central and Southern Asia            Maldives  2014  25-64
# 167          Central and Southern Asia            Maldives  2014  25-64
# 346     Eastern and South-Eastern Asia               China  2010    <15
# 347     Eastern and South-Eastern Asia               China  2010    <15
# 512     Eastern and South-Eastern Asia           Singapore  2013    <15
# 513     Eastern and South-Eastern Asia           Singapore  2013    <15
# 762        Europe and Northern America            Portugal  2018  25-64
# 763        Europe and Northern America            Portugal  2018  25-64
# ...

# %%
# Drop duplicates but keeping the first
df_literacy_rates.drop_duplicates(keep='first', inplace=True)
# Obtain the sum of duplicated to confirm all have been dropped
df_literacy_rates.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Check each string column's value counts for inconsistent values.

# %%
# list of object columns
categorical_columns = df_literacy_rates.select_dtypes('object').columns

# %%
# loop through the list of string columns

for col in categorical_columns:
    # Print the value counts for each column
    print(f"Value counts for {col}:\n")
    print(df_literacy_rates[col].value_counts())
    print("\n" + "-"*50 + "\n")
# Out:
# Value counts for Region:
#
# Region
# Latin America and the Caribbean     940
# Sub-Saharan Africa                  770
# Northern Africa and Western Asia    568
# Europe and Northern America         336
# Central and Southern Asia           307
# Eastern and South-Eastern Asia      282
# Oceania                              96
# Name: count, dtype: int64
#
# --------------------------------------------------
#
# Value counts for Country:
#
# Country
# Mexico                 72
# Uruguay                72
# Brazil                 72
# Palestine              64
# Turkey                 64
#                        ..
# Trinidad and Tobago     8
# Greece                  8
# Estonia                 8
# Hungary                 8
# Antigua and Barbuda     4
# Name: count, Length: 155, dtype: int64
#
# --------------------------------------------------
#
# Value counts for Age:
#
# Age
# <15      840
# 15-24    826
# 25-64    826
# 65+      811
# Name: count, dtype: int64
#
# ...

# %% [markdown]
# Fixing the gender column

# %%
# Replace "F" with "female" & "M" with male
df_literacy_rates['Gender']=df_literacy_rates['Gender'].replace('F', 'female')
df_literacy_rates['Gender']=df_literacy_rates['Gender'].replace('M', 'male')
# Check the value counts again to confirm
df_literacy_rates['Gender'].value_counts()
# Out:
# Gender
# female    1652
# male      1651
# Name: count, dtype: int64

# %% [markdown]
# # Identifying missing values and fixing them

# %%
# number of null values for all columns
null_count=df_literacy_rates.isnull().sum()
null_count
# Out:
# Region           4
# Country          0
# Year             0
# Age              0
# Gender           0
# Literacy rate    5
# dtype: int64

# %%
#filtering null rows in region to see common factors
missing_region = df_literacy_rates[df_literacy_rates['Region'].isnull()]
missing_region
# Out:
#     Region      Country  Year    Age  Gender  Literacy rate
# 2      NaN  Afghanistan  2011  15-24  female       0.321132
# 3      NaN  Afghanistan  2011  15-24    male       0.618791
# 312    NaN   Uzbekistan  2016    65+  female       0.996698
# 313    NaN   Uzbekistan  2016    65+    male       0.999018

# %%
#filter the DataFrame  to display rows where the "Country" is "Afghanistan
#inspecting any common pattern under the country Afghanistan basing on the region
afghanistan_data = df_literacy_rates[df_literacy_rates['Country'] == 'Afghanistan']
afghanistan_data_filtered= afghanistan_data[['Region', 'Country']]
afghanistan_data_filtered
# Out:
#                        Region      Country
# 0   Central and Southern Asia  Afghanistan
# 1   Central and Southern Asia  Afghanistan
# 2                         NaN  Afghanistan
# 3                         NaN  Afghanistan
# 4   Central and Southern Asia  Afghanistan
# 5   Central and Southern Asia  Afghanistan
# 6   Central and Southern Asia  Afghanistan
# 7   Central and Southern Asia  Afghanistan
# 8   Central and Southern Asia  Afghanistan
# 9   Central and Southern Asia  Afghanistan
# 10  Central and Southern Asia  Afghanistan
# 11  Central and Southern Asia  Afghanistan
# 12  Central and Southern Asia  Afghanistan
# 13  Central and Southern Asia  Afghanistan
# 14  Central and Southern Asia  Afghanistan

# %%
#filter the DataFrame  to display rows where the "Country" is "Uzbekistan"
#inspecting any common pattern under the country Uzbekistan basing on the region
Uzbekistan_data = df_literacy_rates[df_literacy_rates['Country'] == 'Uzbekistan']
Uzbekistan_data_filtered = Uzbekistan_data[['Region', 'Country']]
Uzbekistan_data_filtered
# Out:
#                         Region     Country
# 282  Central and Southern Asia  Uzbekistan
# 283  Central and Southern Asia  Uzbekistan
# 284  Central and Southern Asia  Uzbekistan
# 285  Central and Southern Asia  Uzbekistan
# 286  Central and Southern Asia  Uzbekistan
# 287  Central and Southern Asia  Uzbekistan
# 288  Central and Southern Asia  Uzbekistan
# 289  Central and Southern Asia  Uzbekistan
# 290  Central and Southern Asia  Uzbekistan
# 291  Central and Southern Asia  Uzbekistan
# 292  Central and Southern Asia  Uzbekistan
# 293  Central and Southern Asia  Uzbekistan
# 294  Central and Southern Asia  Uzbekistan
# 295  Central and Southern Asia  Uzbekistan
# 296  Central and Southern Asia  Uzbekistan
# 297  Central and Southern Asia  Uzbekistan
# 298  Central and Southern Asia  Uzbekistan
# 299  Central and Southern Asia  Uzbekistan
# 300  Central and Southern Asia  Uzbekistan
# 301  Central and Southern Asia  Uzbekistan
# 302  Central and Southern Asia  Uzbekistan
# ...

# %% [markdown]
# Replacing NaN values in the 'Region' column with 'Central and Southern Asia'
# This decision is based on the filtered data, which shows that the majority of entries for 'Uzbekistan''and 'Afghanistan' are associated with the 'Central and Southern Asia' region

# %%
#  Fill null values in the 'Region' column with "Central and Southern Asia"
df_literacy_rates['Region']=df_literacy_rates['Region'].fillna('Central and Southern Asia')

# %%
df_literacy_rates.isnull().sum()
# Out:
# Region           0
# Country          0
# Year             0
# Age              0
# Gender           0
# Literacy rate    5
# dtype: int64

# %% [markdown]
# Lets fix missing values in Literacy rate column

# %%
#filtering null rows in literacy rate
missing= df_literacy_rates[df_literacy_rates['Literacy rate'].isnull()]
missing
# Out:
#                              Region    Country  Year    Age  Gender  \
# 498  Eastern and South-Eastern Asia  Singapore  2010    65+    male
# 608     Europe and Northern America    Albania  2012  15-24  female
# 753     Europe and Northern America   Portugal  2011  15-24    male
# 855     Europe and Northern America      Spain  2010    <15  female
# 884     Europe and Northern America      Spain  2013  25-64    male
#
#      Literacy rate
# 498            NaN
# 608            NaN
# 753            NaN
# 855            NaN
# 884            NaN

# %%
#checking for outliers to determine whether to use mean or median to fix null values
Q1 = df_literacy_rates['Literacy rate'].quantile(0.25)
Q3 = df_literacy_rates['Literacy rate'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df_literacy_rates[(df_literacy_rates['Literacy rate'] < lower_bound) | (df_literacy_rates['Literacy rate'] > upper_bound)]
outliers
# Out:
#                          Region                      Country  Year    Age  \
# 0     Central and Southern Asia                  Afghanistan  2011    <15
# 2     Central and Southern Asia                  Afghanistan  2011  15-24
# 4     Central and Southern Asia                  Afghanistan  2011  25-64
# 6     Central and Southern Asia                  Afghanistan  2011    65+
# 7     Central and Southern Asia                  Afghanistan  2018    <15
# ...                         ...                          ...   ...    ...
# 3247         Sub-Saharan Africa                       Uganda  2012    65+
# 3255         Sub-Saharan Africa                       Uganda  2018    65+
# 3263         Sub-Saharan Africa  United Republic of Tanzania  2010    65+
# 3271         Sub-Saharan Africa  United Republic of Tanzania  2012    65+
# 3279         Sub-Saharan Africa  United Republic of Tanzania  2015    65+
#
#       Gender  Literacy rate
# 0     female       0.176121
# ...

# %%
#based on the above cell, we have outliers so we shall use the median
literacy_rate_median = df_literacy_rates['Literacy rate'].median()
df_literacy_rates['Literacy rate'].fillna(literacy_rate_median , inplace=True)
df_literacy_rates.isnull().sum()
# Out:
# Region           0
# Country          0
# Year             0
# Age              0
# Gender           0
# Literacy rate    0
# dtype: int64

# %% [markdown]
# # IDENTIFYING UNUSUAL VALUES

# %%
# Identifying rows where the 'Year' column has an unusual value, for example, greater than the current year
unusual_years = df_literacy_rates[df_literacy_rates['Year'] > 2024]
unusual_years
# Out:
#                   Region   Country  Year    Age Gender  Literacy rate
# 3308  Sub-Saharan Africa  Zimbabwe  3014  15-24   male       0.875919

# %%
#I shall assume it was an error, "3014" was supposed to be "2014"
#replace 3014 with 2014
df_literacy_rates['Year'] = df_literacy_rates['Year'].replace(3014, 2014)
#confirm
df_literacy_rates['Year'].value_counts()
# Out:
# Year
# 2018    574
# 2011    455
# 2014    440
# 2010    400
# 2012    344
# 2015    316
# 2013    264
# 2016    264
# 2017    246
# Name: count, dtype: int64

# %%
#reseting the indices
df_literacy_rates.reset_index(drop=True, inplace=True)

# %%
df_literacy_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3303 entries, 0 to 3302
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Region         3303 non-null   object
#  1   Country        3303 non-null   object
#  2   Year           3303 non-null   int64
#  3   Age            3303 non-null   object
#  4   Gender         3303 non-null   object
#  5   Literacy rate  3303 non-null   float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 155.0+ KB

# %%
df_literacy_rates.head()
# Out:
#                       Region      Country  Year    Age  Gender  Literacy rate
# 0  Central and Southern Asia  Afghanistan  2011    <15  female       0.176121
# 1  Central and Southern Asia  Afghanistan  2011    <15    male       0.454171
# 2  Central and Southern Asia  Afghanistan  2011  15-24  female       0.321132
# 3  Central and Southern Asia  Afghanistan  2011  15-24    male       0.618791
# 4  Central and Southern Asia  Afghanistan  2011  25-64  female       0.084128

# %% [markdown]
# # Visualizing the data by plotting

# %% [markdown]
# ### Univariate Exploratory Visualizations

# %% [markdown]
# Distribution of Literacy Rates

# %%
#import libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Histogram of Literacy Rates
ax = sns.histplot(data=df_literacy_rates, x='Literacy rate', binwidth=0.05, stat='percent')
ax.ticklabel_format(style='plain');
ax.tick_params(axis='x', rotation = 45);

plt.title('Literacy Rates Distribution');

# Interpretation:
# The histogram shows how literacy rates are distributed across the dataset.
# This helps to identify if literacy rates are generally low or high, and if there are any major outliers.
#percentage on the y-axis allows for a better understanding of the relative frequency of literacy rates.

# %% [markdown]
# Gender distribution

# %%
# Count plot for Gender Distribution
sns.countplot(data=df_literacy_rates, x='Gender', hue='Gender', palette='pastel', legend=False)

# Add title
plt.title('Gender Distribution in Literacy Rates');

# Interpretation:
# This chart shows whether there is an equal number of male and female literacy rate entries.
# It gives a sense of how balanced the data is between genders.

# %% [markdown]
# ## Multivariante Analysis

# %% [markdown]
# ### Literacy Rates by Region and Gender

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=df_literacy_rates, x='Region', y='Literacy rate', hue='Gender')
plt.xticks(rotation=45)
plt.title('Literacy Rates by Region and Gender')
plt.show()

# Interpretation:
# This plot helps identify if certain regions have higher or lower literacy rates for males vs. females.
# It can highlight disparities between genders and regions, which could guide where efforts need to be focused.

# %% [markdown]
# ###  Literacy Rates by Gender and Age

# %%
# Line plot for Literacy Rate by Gender And Age
plt.figure(figsize=(10,6))
sns.lineplot(data=df_literacy_rates, x='Age', y='Literacy rate', hue='Gender', marker='o')
plt.title(' Literacy Rates by Gender and Age')

plt.show()

# Interpretation:
# It can highlight disparities between genders and age, which could guide where efforts need to be focused.
# It helps to identify the impact of past projects.

# %% [markdown]
# # General Insights and conclusion

# %% [markdown]
# Key Insights:
#
# **Gender Gap in Literacy:**
#
# Across most regions shown in the graph, there is a noticeable gap in literacy rates between males and females, with males generally having higher literacy rates. This gender disparity is particularly in regions like Central and Southern Asia and Sub-Saharan Africa.
# Strategy Insight: The organization may want to focus on addressing the literacy gap between genders, especially by providing targeted literacy programs aimed at empowering young females in regions with significant disparities.
#
# **Regional Differences:**
#
# Some regions, like Northern America and Oceania, have relatively high literacy rates with minimal gender disparity. These regions may not need as much focus when it comes to increasing overall literacy rates.
# On the other hand, regions such as Sub-Saharan Africa,Central and Southern Asia and Northern Africa have lower literacy rates overall, making them high-priority areas for intervention.
# Strategy Insight: The organization could concentrate its efforts on regions with both low literacy rates and large gender gaps, as addressing these challenges may yield the most significant improvement in overall youth literacy.
#
# **Age as a Factor:**
#
#  Youth literacy rates tend to be higher for individuals aged 15-24 compared to those under 15 and the old age. This suggests that literacy programs aimed at younger children (below age 15) may require more attention.
# Strategy Insight: The organization might consider focusing on early-age literacy programs to address low literacy rates before children reach adolescence, thus setting a stronger foundation for future literacy development and also adult education programs.
#
# **Conclusion:**
# To maximize its impact, the non-profit organization should:
#
# Target regions with the largest gender literacy gaps and overall low literacy rates, such as Sub-Saharan Africa, Northern Africa, and Central and Southern Asia.
# Focus on youth literacy programs, particularly for females under the age of 15, as addressing this demographic could lead to the most significant long-term benefits.
# Adopt localized strategies to address cultural and socio-economic barriers that contribute to gender inequality in education, working with community leaders and stakeholders to ensure sustainable changes.

# %% [markdown]
# **THIS IS DATASET TWO, SALES_PREDICTIONS_2023**
# ---

# %%
#loading dataset 2
fpath2='/content/drive/MyDrive/Course 1/Week 2/Data/sales_predictions_2023.csv'

df_sales= pd.read_csv(fpath2)

# Display the first 5 rows
df_sales.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# Display the info for the dataframe
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# # Checking Data Types

# %%
#viewing only object columns
df_sales.select_dtypes('object')
# Out:
#      Item_Identifier Item_Fat_Content              Item_Type  \
# 0              FDA15          Low Fat                  Dairy
# 1              DRC01          Regular            Soft Drinks
# 2              FDN15          Low Fat                   Meat
# 3              FDX07          Regular  Fruits and Vegetables
# 4              NCD19          Low Fat              Household
# ...              ...              ...                    ...
# 8518           FDF22          Low Fat            Snack Foods
# 8519           FDS36          Regular           Baking Goods
# 8520           NCJ29          Low Fat     Health and Hygiene
# 8521           FDN46          Regular            Snack Foods
# 8522           DRG01          Low Fat            Soft Drinks
#
#      Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# 0               OUT049      Medium               Tier 1  Supermarket Type1
# 1               OUT018      Medium               Tier 3  Supermarket Type2
# ...

# %%
#viewing only numeric columns
df_sales.select_dtypes('number')
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0           9.300         0.016047  249.8092                       1999
# 1           5.920         0.019278   48.2692                       2009
# 2          17.500         0.016760  141.6180                       1999
# 3          19.200         0.000000  182.0950                       1998
# 4           8.930         0.000000   53.8614                       1987
# ...           ...              ...       ...                        ...
# 8518        6.865         0.056783  214.5218                       1987
# 8519        8.380         0.046982  108.1570                       2002
# 8520       10.600         0.035186   85.1224                       2004
# 8521        7.210         0.145221  103.1332                       2009
# 8522       14.800         0.044878   75.4670                       1997
#
#       Item_Outlet_Sales
# 0             3735.1380
# 1              443.4228
# 2             2097.2700
# ...

# %% [markdown]
# # Checking for Duplicates

# %%
duplicated_rows= df_sales.duplicated()
# Get the sum of duplicated_rows
duplicated_rows.sum()
# Out:
# 0

# %% [markdown]
# # Checking if thers's a column with 100% unique values

# %%
unique_counts=df_sales.nunique()
unique_counts
# Out:
# Item_Identifier              1559
# Item_Weight                   415
# Item_Fat_Content                5
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     3
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64

# %%
# determine if any of the columns have 100% unique values.
# Get the total number of rows in the DataFrame
total_rows = len(df_sales)
# Check which columns have 100% unique values
columns_with_all_unique = unique_counts[unique_counts == total_rows]
columns_with_all_unique
# Out:
# Series([], dtype: int64)

# %% [markdown]
# # Identifying missing values

# %%
# Get the number of null values for all columns
null_count=df_sales.isnull().sum()
null_count
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# calculate the percentage of null values for each column.
null_percent = null_count/len(df_sales) * 100
null_percent
# Out:
# Item_Identifier               0.000000
# Item_Weight                  17.165317
# Item_Fat_Content              0.000000
# Item_Visibility               0.000000
# Item_Type                     0.000000
# Item_MRP                      0.000000
# Outlet_Identifier             0.000000
# Outlet_Establishment_Year     0.000000
# Outlet_Size                  28.276428
# Outlet_Location_Type          0.000000
# Outlet_Type                   0.000000
# Item_Outlet_Sales             0.000000
# dtype: float64

# %%
# Visualize the missing values using the missingno package's matrix plot.
import missingno as msno
msno.matrix(df_sales);

# %% [markdown]
# fixing the null values in Item_weight column

# %%
# Check for outliers in Item_Weight
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = df_sales['Item_Weight'].quantile(0.25)
Q3 = df_sales['Item_Weight'].quantile(0.75)

# Calculate the IQR
IQR = Q3 - Q1

#  Define lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df_sales[(df_sales['Item_Weight'] < lower_bound) | (df_sales['Item_Weight'] > upper_bound)]
outliers
# Out:
# Empty DataFrame
# Columns: [Item_Identifier, Item_Weight, Item_Fat_Content, Item_Visibility, Item_Type, Item_MRP, Outlet_Identifier, Outlet_Establishment_Year, Outlet_Size, Outlet_Location_Type, Outlet_Type, Item_Outlet_Sales]
# Index: []

# %%
#since no outliers, we shall use the mean
item_weight_mean= df_sales['Item_Weight'].mean()
#fill in the missing values with mean
df_sales['Item_Weight'].fillna(item_weight_mean , inplace=True)
df_sales.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# fixing the null values in Outlet_Size column

# %%
#filtering null rows in outlet size to see common factors
missing = df_sales[df_sales['Outlet_Size'].isnull()]
missing
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3              FDX07       19.200          Regular         0.000000
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 25             NCD06       13.000          Low Fat         0.099887
# 28             FDE51        5.925          Regular         0.161467
# ...              ...          ...              ...              ...
# 8502           NCH43        8.420          Low Fat         0.070712
# 8508           FDW31       11.350          Regular         0.043246
# 8509           FDG45        8.100          Low Fat         0.214306
# 8514           FDA01       15.000          Regular         0.054489
# 8519           FDS36        8.380          Regular         0.046982
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3     Fruits and Vegetables  182.0950            OUT010
# ...

# %%
#we use mode to fill in the missing values
outlet_size_mode=df_sales['Outlet_Size'].mode()
#outlet_size_mode
#we shall use the mode which is "Medium" as our placeholder
df_sales['Outlet_Size'].fillna('Medium' , inplace=True)

df_sales.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
#confirm no missing values
import missingno as msno
msno.matrix(df_sales);

# %% [markdown]
# # Checking for consistency

# %%
#looping through categorical columns to get the value count for each
string_columns = df_sales.select_dtypes('object').columns
for col in string_columns:
    # Print the value counts for each column
    print(f"Value counts for {col}:\n")
    print(df_sales[col].value_counts())
    print("\n" + "-"*40 + "\n")
# Out:
# Value counts for Item_Identifier:
#
# Item_Identifier
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
#          ..
# FDY43     1
# FDQ60     1
# FDO33     1
# DRF48     1
# FDC23     1
# Name: count, Length: 1559, dtype: int64
#
# ----------------------------------------
#
# Value counts for Item_Fat_Content:
#
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64
#
# ----------------------------------------
#
# Value counts for Item_Type:
#
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# ...

# %%
df_sales['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64

# %%
# Dictionary for replacements so as to have consistent values
replacement_dict = {
    'Low Fat': 'Low Fat',
    'LF': 'Low Fat',
    'low fat': 'Low Fat',
    'Regular': 'Regular',
    'reg': 'Regular'
}

# Replace the values in the 'Item_Fat_Content' column
df_sales['Item_Fat_Content'] = df_sales['Item_Fat_Content'].replace(replacement_dict)

#confirming
df_sales['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5517
# Regular    3006
# Name: count, dtype: int64

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df_sales.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# # Visualizing data by plotting

# %% [markdown]
# ### Univariante Analysis

# %% [markdown]
# Distribution of Item_Visibility

# %%
# Histogram of Item Visibility
plt.figure(figsize=(10,6))
sns.histplot(df_sales['Item_Visibility'], bins=20, kde=True)
plt.title('Distribution of Item Visibility')
plt.show()

# Interpretation:
# This plot shows the distribution of item visibility in the store. We can observe the range where most of the items fall in terms of their visibility.

# %% [markdown]
# Distribution of Item_MRP

# %%
# Histogram of Item MRP
plt.figure(figsize=(10,6))
sns.histplot(df_sales['Item_MRP'], bins=20, kde=True, color='orange')
plt.title('Distribution of Item MRP')
plt.show()

# Interpretation:
# The distribution of the MRP helps us understand how items are priced. Peaks in this distribution could show popular price ranges for items.

# %% [markdown]
# # Multivariante Analysis

# %% [markdown]
#  Average Item_Outlet_Sales by Outlet_Type and Outlet_Size

# %%
# Bar plot of Item Outlet Sales by Outlet Type and Size
plt.figure(figsize=(12, 6))
sns.barplot(x='Outlet_Type', y='Item_Outlet_Sales', hue='Outlet_Size', data=df_sales)
plt.title('Average Sales by Outlet Type and Size')
plt.xticks(rotation=45)
plt.legend(title='Outlet Size')
plt.show()

# Interpretation:
# This visualization allows us to compare how different outlet types (Supermarkets, Grocery Stores) perform in terms of sales and whether outlet size has any significant effect.

# %% [markdown]
#  Item Fat Content vs Item Sales by Outlet Location Type

# %%
# Boxplot of Item Outlet Sales by Fat Content and Outlet Location Type
plt.figure(figsize=(12,6))
sns.boxplot(x='Item_Fat_Content', y='Item_Outlet_Sales', hue='Outlet_Location_Type', data=df_sales)
plt.title('Sales by Fat Content and Outlet Location Type')
plt.show()

# Interpretation:
# This plot will help identify whether there are any significant differences in sales for items with d

# %% [markdown]
# # General Insights and Conclusions

# %% [markdown]
# **Sales by Outlet Type and Size**
#
# Supermarket Type 3 (Medium size) has significantly higher sales compared to other outlet types, indicating that this format performs best. This suggests that medium-sized outlets in Type 3 locations are optimal for driving sales.
# Grocery Stores have the lowest sales overall, which could indicate either lower demand in these areas or that customers prefer larger outlets with a broader selection.
# Across Supermarket Type 1, the size of the outlet (medium, high, small) has relatively similar sales, indicating size is less influential in this type of outlet.
# Supermarket Type 2 (Medium) shows lower sales than Type 1 or Type 3, suggesting it may not be optimized for customer traffic or product mix.
#
# **Actionable Insights:**
#
# Focus on expanding or optimizing Supermarket Type 3 outlets, particularly in medium sizes, as they seem to offer the best return.
# Grocery Stores may need restructuring or repositioning to meet demand
#
# **Sales by Fat Content and Outlet Location Type**
#
# Sales for regular-fat products appear to be slightly higher than for low-fat products across most outlet types, suggesting that customers may prefer regular-fat products.
# Tier 1 locations tend to have lower median sales compared to Tier 3 across both low-fat and regular products, indicating that Tier 3 locations may cater to higher-spending customers or have better foot traffic.
# Tier 3 consistently shows more outliers, indicating a broader range of customer spending patterns, possibly due to higher population or wealthier customers in these areas.
#
# **Actionable Insights:**
#
# Consider expanding the range of regular-fat products to cater to customer preferences.
# Tier 3 outlets seem to present more growth opportunities for higher sales; these should be the focus for marketing efforts.
# Tier 1 locations may need a different strategy, such as adjusting pricing or promotions, to boost sales.
#
# **General Observations:**
#
# Outlet Type plays a major role in sales, with medium-sized supermarkets performing well across the board.
# Location Type (Tier 3) and product preferences (regular vs low-fat) could be key areas to focus on for improving sales.
#
# **Based on these insights, some strategies for improvement could include:**
#
# Expanding successful outlet types in high-performing locations (Supermarket Type 3 in Tier 3).
# Reducing the footprint of low-performing outlet types (e.g., Grocery Stores)
# Tailoring product offerings to align with customer preferences in specific locations, such as prioritizing regular-fat items in Tier 3.
